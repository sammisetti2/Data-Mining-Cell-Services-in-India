# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

##storing Total Dataset which has been sampled and cleaned into one dataframe
address = "../Data/Sampled and Cleaned data/TotalData_Cleaned_Sampled.csv"
data = pd.read_csv(address)
df = pd.DataFrame(data)

#creating one dataframe to store outliers
dfi = pd.DataFrame()

#Keeping track of standard deviation and mean for both speed and signal strength values
x1 = df['speed'].std()
y1 = df['speed'].mean()
x2 = df['signal_strength'].std()
y2 = df['signal_strength'].mean()

#applying z score normalization
df['signal_strength']=(df['signal_strength']-df['signal_strength'].mean())/df['signal_strength'].std()
df['speed']=(df['speed']-df['speed'].mean())/df['speed'].std()

#Tested all the outlier thresholds to find that only outliers exist with z score values greater than 3 for speed 
#so storing them in dfi
dfi = dfi.append(df.loc[df['speed'] > 3]).copy()

#Removing all outliers
df = df.loc[df['speed'] <= 3].copy()

#converting normalized values back to real values in outlier dataframe
dfi['speed']=dfi['speed']*x1+y1
dfi['signal_strength']=dfi['signal_strength']*x2+y2

#converting normalized values back to real values in main dataframe which has no outliers
df['speed']=df['speed']*x1+y1
df['signal_strength']=df['signal_strength']*x2+y2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-68973dab3cce> in <module>
#       6 ##storing Total Dataset which has been sampled and cleaned into one dataframe
#       7 address = "DMFinalTerm_TeamID_39/Data/Sampled and Cleaned data/TotalData_Cleaned_Sampled.csv"
# ----> 8 data = pd.read_csv(address)
#       9 df = pd.DataFrame(data)
#      10
#
# c:\users\pranav\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# c:\users\pranav\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# c:\users\pranav\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# c:\users\pranav\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# c:\users\pranav\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File DMFinalTerm_TeamID_39/Data/Sampled and Cleaned data/TotalData_Cleaned_Sampled.csv does not exist: 'DMFinalTerm_TeamID_39/Data/Sampled and Cleaned data/TotalData_Cleaned_Sampled.csv'

# %%
#insert additional column
dfi.insert(8, 'Count', 1)
dfi
# Out:
#        service_provider technology       d_u    speed  signal_strength  \
# 17                  JIO         4G  download  62441.0            -65.0
# 31                  JIO         4G  download  75071.0            -62.0
# 44                  JIO         4G  download  77141.0            -66.0
# 63                  JIO         4G  download  80360.0            -63.0
# 67                  JIO         4G  download  74237.0            -59.0
# ...                 ...        ...       ...      ...              ...
# 340972              JIO         4G  download  65624.0            -52.0
# 340983              JIO         4G  download  67291.0            -52.0
# 340987              JIO         4G  download  61604.0            -52.0
# 341676              JIO         4G  download  90568.0            -84.0
# 342179           AIRTEL         4G  download  60402.0            -73.0
#
#              state  Month  Year  Count
# 17         Gujarat   July  2018      1
# 31         Gujarat   July  2018      1
# 44         Gujarat   July  2018      1
# 63         Gujarat   July  2018      1
# 67         Gujarat   July  2018      1
# ...            ...    ...   ...    ...
# 340972       Bihar  March  2019      1
# 340983       Bihar  March  2019      1
# 340987       Bihar  March  2019      1
# 341676       Assam  March  2019      1
# 342179  North East  March  2019      1
#
# [12188 rows x 9 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.figure(figsize=(100,100))
sns.set(style="darkgrid")

# %%
plot1 = dfi.groupby('service_provider').Count.sum().plot(kind ='bar')

# %%
plot2 = sns.boxplot(y='speed', x='service_provider', data=dfi, width=0.7, palette="colorblind")

# %%
plot3 = sns.catplot(y='speed', x='service_provider', hue='Year', data=dfi, palette="colorblind")

# %%
plot4 = sns.catplot(x='service_provider',y='speed',hue='state',kind='point',data=dfi)
plot4.fig.autofmt_xdate()
